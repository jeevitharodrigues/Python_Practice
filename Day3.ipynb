# %% [markdown]
# ##Pandas

# %%
import pandas as pd

# %%
df=pd.DataFrame({'col1':[1,2,3,4,5],'col2':['abc','bcd','cde','dcf','efg']})
df
# Out:
#    col1 col2
# 0     1  abc
# 1     2  bcd
# 2     3  cde
# 3     4  dcf
# 4     5  efg

# %%
df=pd.read_csv("/content/jsonoutput.csv")
df.head()
# Out:
#   gender       age gross_income            segment  num_credit_cards  \
# 0      M  21 years   $ 79070.91        Individuals                 0
# 1      M  23 years  $ 178270.68  College_Graduated                 0
# 2      M  24 years   $ 31243.56  College_Graduated                 0
# 3      M  24 years  $ 130740.54  College_Graduated                 0
# 4      M  31 years  $ 112975.17        Individuals                 0
#
#   tiprel_1mes  ind_actividad_cliente  num_Products  num_loans  duration
# 0           I                      0             1          0      1035
# 1           I                      0             1          0      1097
# 2           I                      1             1          0      1866
# 3           I                      0             1          0      1440
# 4           I                      0             0          0       376

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54030 entries, 0 to 54029
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   gender                 54030 non-null  object
#  1   age                    54030 non-null  object
#  2   gross_income           54030 non-null  object
#  3   segment                54030 non-null  object
#  4   num_credit_cards       54030 non-null  int64
#  5   tiprel_1mes            54030 non-null  object
#  6   ind_actividad_cliente  54030 non-null  int64
#  7   num_Products           54030 non-null  int64
#  8   num_loans              54030 non-null  int64
#  9   duration               54030 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 4.1+ MB

# %%
df.shape
# Out:
# (54030, 10)

# %%
for row in range(df.shape[0]):
  print(df.loc[row,'gross_income'])
  break
# Out:
# $ 79070.91

# %%
for row in range(df.shape[0]):
  df.loc[row,'gross_income']=float(df.loc[row,'gross_income'].split(" ")[-1])

df
# Out:
#       gender       age gross_income            segment  num_credit_cards  \
# 0          M  21 years     79070.91        Individuals                 0
# 1          M  23 years    178270.68  College_Graduated                 0
# 2          M  24 years     31243.56  College_Graduated                 0
# 3          M  24 years    130740.54  College_Graduated                 0
# 4          M  31 years    112975.17        Individuals                 0
# ...      ...       ...          ...                ...               ...
# 54025      M  24 years     47237.01  College_Graduated                 0
# 54026      F  46 years    106930.05        Individuals                 1
# 54027      M  24 years    185323.05  College_Graduated                 0
# 54028      F  27 years     65246.79  College_Graduated                 0
# 54029      M  20 years    180678.48  College_Graduated                 0
#
#       tiprel_1mes  ind_actividad_cliente  num_Products  num_loans  duration
# ...

# %%
a="$ 79070.91"

float(a.split(" ")[-1])
# Out:
# 79070.91

# %%
df['gross_income']=df['gross_income'].apply(lambda x: float(x.split(" ")[-1]))  #using lambda function

# %%
df
# Out:
#       gender       age  gross_income            segment  num_credit_cards  \
# 0          M  21 years      79070.91        Individuals                 0
# 1          M  23 years     178270.68  College_Graduated                 0
# 2          M  24 years      31243.56  College_Graduated                 0
# 3          M  24 years     130740.54  College_Graduated                 0
# 4          M  31 years     112975.17        Individuals                 0
# ...      ...       ...           ...                ...               ...
# 54025      M  24 years      47237.01  College_Graduated                 0
# 54026      F  46 years     106930.05        Individuals                 1
# 54027      M  24 years     185323.05  College_Graduated                 0
# 54028      F  27 years      65246.79  College_Graduated                 0
# 54029      M  20 years     180678.48  College_Graduated                 0
#
#       tiprel_1mes  ind_actividad_cliente  num_Products  num_loans  duration
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54030 entries, 0 to 54029
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   gender                 54030 non-null  object
#  1   age                    54030 non-null  object
#  2   gross_income           54030 non-null  float64
#  3   segment                54030 non-null  object
#  4   num_credit_cards       54030 non-null  int64
#  5   tiprel_1mes            54030 non-null  object
#  6   ind_actividad_cliente  54030 non-null  int64
#  7   num_Products           54030 non-null  int64
#  8   num_loans              54030 non-null  int64
#  9   duration               54030 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 4.1+ MB

# %%
df['gross_income']=df['gross_income'].apply(lambda x: x.split(" ")[-1])  #using lambda function

# %%
df['gross_income']=df['gross_income'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54030 entries, 0 to 54029
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   gender                 54030 non-null  object
#  1   age                    54030 non-null  object
#  2   gross_income           54030 non-null  float64
#  3   segment                54030 non-null  object
#  4   num_credit_cards       54030 non-null  int64
#  5   tiprel_1mes            54030 non-null  object
#  6   ind_actividad_cliente  54030 non-null  int64
#  7   num_Products           54030 non-null  int64
#  8   num_loans              54030 non-null  int64
#  9   duration               54030 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 4.1+ MB

# %%
df['gross_income']=df.apply(lambda x: x['gross_income'].split(" ")[-1],axis=1)

# %%
df
# Out:
#       gender       age gross_income            segment  num_credit_cards  \
# 0          M  21 years     79070.91        Individuals                 0
# 1          M  23 years    178270.68  College_Graduated                 0
# 2          M  24 years     31243.56  College_Graduated                 0
# 3          M  24 years    130740.54  College_Graduated                 0
# 4          M  31 years    112975.17        Individuals                 0
# ...      ...       ...          ...                ...               ...
# 54025      M  24 years     47237.01  College_Graduated                 0
# 54026      F  46 years    106930.05        Individuals                 1
# 54027      M  24 years    185323.05  College_Graduated                 0
# 54028      F  27 years     65246.79  College_Graduated                 0
# 54029      M  20 years    180678.48  College_Graduated                 0
#
#       tiprel_1mes  ind_actividad_cliente  num_Products  num_loans  duration
# ...

# %%
df2=df.drop(['segment','num_loans'],axis=1)
df2
# Out:
#       gender       age gross_income  num_credit_cards tiprel_1mes  \
# 0          M  21 years     79070.91                 0           I
# 1          M  23 years    178270.68                 0           I
# 2          M  24 years     31243.56                 0           I
# 3          M  24 years    130740.54                 0           I
# 4          M  31 years    112975.17                 0           I
# ...      ...       ...          ...               ...         ...
# 54025      M  24 years     47237.01                 0           I
# 54026      F  46 years    106930.05                 1           A
# 54027      M  24 years    185323.05                 0           I
# 54028      F  27 years     65246.79                 0           I
# 54029      M  20 years    180678.48                 0           A
#
#        ind_actividad_cliente  num_Products  duration
# 0                          0             1      1035
# 1                          0             1      1097
# ...
